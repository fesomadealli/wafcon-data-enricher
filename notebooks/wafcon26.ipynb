# %%
# !pip install pandas matplotlib seaborn plottable python-dotenv
# Out:
# WARNING: Connection interrupted while downloading.
# WARNING: Attempting to resume incomplete download (2.4 MB/9.3 MB, attempt 1)
# WARNING: Connection interrupted while downloading.
# WARNING: Attempting to resume incomplete download (3.4 MB/9.3 MB, attempt 2)
# WARNING: Connection interrupted while downloading.
# WARNING: Attempting to resume incomplete download (5.0 MB/9.3 MB, attempt 3)
# WARNING: Connection interrupted while downloading.
# WARNING: Attempting to resume incomplete download (5.5 MB/12.5 MB, attempt 1)
# ...
#   Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.11.1-cp313-cp313-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached plottable-0.1.5-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached python_dotenv-1.2.3-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached numpy-2.5.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...

# %%
import pandas as pd
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 from pathlib import Path
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# project_root = Path(r"C:\Users\user\Downloads\codebook\wafcon-data-enricher").resolve()

# project_root
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 project_root = Path(r"C:\Users\user\Downloads\codebook\wafcon-data-enricher").resolve()
#       2
#       3 project_root
#
# NameError: name 'Path' is not defined

# %%
df_results = pd.read_csv("wafcon_results_compiled.csv")

# %%
# df_results = pd.read_csv(project_root / "data" / "raw" / "wafcon_results_compiled.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1496/432482781.py in <cell line: 0>()
# ----> 1 df_results = pd.read_csv(project_root / "data" / "raw" / "wafcon_results_compiled.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_results = pd.read_csv(project_root / "data" / "raw" / "wafcon_results_compiled.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1496/432482781.py in <cell line: 0>()
# ----> 1 df_results = pd.read_csv(project_root / "data" / "raw" / "wafcon_results_compiled.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
